# %%
import tabula
import pandas as pd
from IPython.core.display import display_html
import re
import openpyxl

# %%
lista_cotacao_01 = tabula.read_pdf(r"cdp19023051109003634960000000.pdf", pages="all")
print(len(lista_cotacao_01))
# Out:
# 72

# %%
for cotacao_01 in lista_cotacao_01:
    display(cotacao_01)
# Out:
#                                           Ordem\r1  Produto\r41006/106  \
# 0                                     % ICMS\r12.0         % IPI\r0,00
# 1              Descrição\rALICATE CORTE DIAGONAL 6                 NaN
# 2                                         Ordem\r2  Produto\r44115/013
# 3                                     % ICMS\r12.0         % IPI\r0,00
# 4    Descrição\rCH FENDA CHATA ISOLADA 3X150 1/8X6                 NaN
# 5                                         Ordem\r3  Produto\r44115/023
# 6                                     % ICMS\r12.0         % IPI\r0,00
# 7   Descrição\rCH FENDA CHATA ISOLADA 5X150 3/16X6                 NaN
# 8                                         Ordem\r4  Produto\r44115/033
# 9                                     % ICMS\r12.0         % IPI\r0,00
# 10  Descrição\rCH FENDA CHATA ISOLADA 6X200 -1/4X8                 NaN
# 11                                        Ordem\r5  Produto\r44116/013
# ...

# %% [markdown]
# #PAGINA_01_TRAMONTINA

# %%
#Leitura do pdf
lista1_cotacao_02 = tabula.read_pdf(r"cdp19023051109003634960000000.pdf", pages="all")
pagina1_cotacao_02 = lista1_cotacao_02[0]
pagina1_cotacao_02.columns = ['indice01','indice02','indice03','indice04','indice05','indice06','indice07','indice08','indice09','indice10']
#Descrição material - Filtragem de descirção somente da tabela 01
descricao_material1 = pagina1_cotacao_02[pagina1_cotacao_02['indice01'].str.contains('Descrição\r')]
descricao_material1 = descricao_material1['indice01'].str.replace('Descrição\r','')
descricao_material1 = descricao_material1.reset_index(drop=True)
#Preço_Unitário - FIltragem de preço unitário da tabela1
preco_unitario1 = pagina1_cotacao_02[pagina1_cotacao_02['indice04'].str.len() > 0]
preco_unitario1 = pagina1_cotacao_02['indice04'].str.contains('Preço Unitário sem I\r')
preco_unitario1 = pagina1_cotacao_02['indice04'].str.replace('Preço Unitário sem I\r','')
preco_unitario1 = preco_unitario1[preco_unitario1.str.len() > 0]
preco_unitario1 = preco_unitario1[~preco_unitario1.str.contains('Emb.\r1')]
preco_unitario1 = preco_unitario1.reset_index(drop=True)
preco_unitario1 = preco_unitario1.apply(lambda x: str(x).replace(",","."))
preco_unitario1 = preco_unitario1.astype('float64')
#Preço total - fitragem de preço total
preco_total1 = pagina1_cotacao_02[pagina1_cotacao_02['indice05'].str.len() > 0]
preco_total1 = pagina1_cotacao_02['indice05'].str.contains('I Preço Total\r')
preco_total1 = pagina1_cotacao_02['indice05'].str.replace('I Preço Total\r','')
preco_total1 = preco_total1[preco_total1.str.len() > 0]
preco_total1 = preco_total1[~preco_total1.str.contains('Qtde.\r30')]
preco_total1 = preco_total1.reset_index(drop=True)
preco_total1 = preco_total1.apply(lambda x: str(x).replace(".",""))
preco_total1 = preco_total1.apply(lambda x: str(x).replace(",","."))
preco_total1 = preco_total1.astype('float64')
#mesclando os dados atrávés de cada indice formando uma tabela
df_mesclar01= descricao_material1.to_frame().merge(preco_unitario1,left_index=True,right_index=True)
df_mesclar01= descricao_material1.to_frame().merge(preco_unitario1,left_index=True,right_index=True)
Tabela_01= df_mesclar01.merge(preco_total1,left_index=True,right_index=True)
Tabela_01['indice02'] = Tabela_01['indice05'] / Tabela_01['indice04']
display(Tabela_01)
# Out:
#                               indice01  indice04  indice05  indice02
# 0             ALICATE CORTE DIAGONAL 6     20.87    1252.2      60.0
# 1   CH FENDA CHATA ISOLADA 3X150 1/8X6      8.02     240.6      30.0
# 2  CH FENDA CHATA ISOLADA 5X150 3/16X6      9.24     277.2      30.0
# 3  CH FENDA CHATA ISOLADA 6X200 -1/4X8     13.24     397.2      30.0
# 4  CH. FENDA CRUZ. ISOLADA 3X150 1/8X6      9.05     271.5      30.0
# 5  CH FENDA CRUZ. ISOLADA 5X150 3/16X6      9.86     295.8      30.0

# %% [markdown]
# #PAGINA_02_TRAMONTINA

# %%
# #Leitura do pdf
lista_cotacao_02 = tabula.read_pdf(r"C:\Users\Hely Ribeiro Menezes\Documents\One Engenharia\Colab Notebooks\COTAÇAO_FERRAMENTAS\cdp19023051109003634960000000.pdf", pages="2")
pagina2_cotacao_02 = lista_cotacao_02[0]
pagina2_cotacao_02.columns = ['indice01','indice02','indice03','indice04','indice05','indice06','indice07','indice08','indice09','indice10']
#Descrição material - Filtragem de descirção somente da tabela 01
descricao_material2 = pagina2_cotacao_02[pagina2_cotacao_02['indice01'].str.contains('Descrição\r')]
descricao_material2 = descricao_material2['indice01'].str.replace('Descrição\r','')
descricao_material2 = descricao_material2.reset_index(drop=True)
#Preço_Unitário - FIltragem de preço unitário da tabela1
preco_unitario2 = pagina2_cotacao_02[pagina2_cotacao_02['indice04'].str.len() > 0]
preco_unitario2 = pagina2_cotacao_02['indice04'].str.contains('Preço Unitário sem I\r')
preco_unitario2 = pagina2_cotacao_02['indice04'].str.replace('Preço Unitário sem I\r','')
preco_unitario2 = preco_unitario2[preco_unitario2.str.len() > 0]
preco_unitario2 = preco_unitario2[~preco_unitario2.str.contains('Emb.\r')]
preco_unitario2 = preco_unitario2.reset_index(drop=True)
preco_unitario2 = preco_unitario2.apply(lambda x: str(x).replace(",","."))
preco_unitario2 = preco_unitario2.astype('float64')
#Preço total - fitragem de preço total
preco_total2 = pagina2_cotacao_02[pagina2_cotacao_02['indice05'].str.len() > 0]
preco_total2 = pagina2_cotacao_02['indice05'].str.contains('I Preço Total\r')
preco_total2 = pagina2_cotacao_02['indice05'].str.replace('I Preço Total\r','')
preco_total2 = preco_total2[preco_total2.str.len() > 0]
preco_total2 = preco_total2[~preco_total2.str.contains('Qtde.\r')]
preco_total2 = preco_total2.reset_index(drop=True)
preco_total2 = preco_total2.apply(lambda x: str(x).replace(".",""))
preco_total2 = preco_total2.apply(lambda x: str(x).replace(",","."))
preco_total2 = preco_total2.astype('float64')
#mesclando os dados atrávés de cada indice formando uma tabela
df_mesclar02= descricao_material2.to_frame().merge(preco_unitario2,left_index=True,right_index=True)
df_mesclar02= descricao_material2.to_frame().merge(preco_unitario2,left_index=True,right_index=True)
Tabela_02= df_mesclar02.merge(preco_total2,left_index=True,right_index=True)
Tabela_02['indice02'] = Tabela_02['indice05'] / Tabela_02['indice04']
display(Tabela_02)
# Out:
#                               indice01  indice04  indice05   indice02
# 0  CH. FENDA CRUZ. ISOLADA 6X200 1/4X8   13.3500    400.50  30.000000
# 1   CH. DE FENDA P. CHATA 3X125 -1/8X5    3.9758    238.55  60.000503
# 2  CH. DE FENDA P. CHATA 5X150 -3/16X6    5.4258    325.55  60.000369
# 3   CH. DE FENDA P. CHATA 6X200 -1/4X8    7.4200    445.20  60.000000
# 4   CH. DE FENDA P. CRUZ. 3X125 -1/8X5    4.8658    291.95  60.000411
# 5  CH. DE FENDA P. CRUZ. 5X150 -3/16X6    5.7958    347.75  60.000345
# 6   CH. DE FENDA P. CRUZ. 6X200 -1/4X8    9.3458    560.75  60.000214
# 7       NIVEL MAGNETICO DE ALUMINIO 12   37.3183   2239.10  60.000054

# %% [markdown]
# #PAGINA_03_TRAMONTINA

# %%
#Leitura do pdf
lista1_cotacao_03 = tabula.read_pdf(r"C:\Users\Hely Ribeiro Menezes\Documents\One Engenharia\Colab Notebooks\COTAÇAO_FERRAMENTAS\cdp19023051109003634960000000.pdf", pages="3")
pagina3_cotacao_02 = lista1_cotacao_03[0]
pagina3_cotacao_02.columns = ['indice01','indice02','indice03','indice04','indice05','indice06','indice07','indice08','indice09','indice10']
#Descrição material - Filtragem de descirção somente da tabela 01
descricao_material3 = pagina3_cotacao_02[pagina3_cotacao_02['indice01'].str.contains('Descrição\r')]
descricao_material3 = descricao_material3['indice01'].str.replace('Descrição\r','')
descricao_material3 = descricao_material3.reset_index(drop=True)
#Preço_Unitário - FIltragem de preço unitário da tabela1
preco_unitario3 = pagina3_cotacao_02[pagina3_cotacao_02['indice04'].str.len() > 0]
preco_unitario3 = pagina3_cotacao_02['indice04'].str.contains('Preço Unitário sem I\r')
preco_unitario3 = pagina3_cotacao_02['indice04'].str.replace('Preço Unitário sem I\r','')
preco_unitario3 = preco_unitario3[preco_unitario3.str.len() > 0]
preco_unitario3 = preco_unitario3[~preco_unitario3.str.contains('Emb.\r1')]
preco_unitario3 = preco_unitario3.reset_index(drop=True)
preco_unitario3 = preco_unitario3.apply(lambda x: str(x).replace(",","."))
preco_unitario3 = preco_unitario3.astype('float64')
#Preço total - fitragem de preço total
preco_total3 = pagina3_cotacao_02[pagina3_cotacao_02['indice05'].str.len() > 0]
preco_total3 = pagina3_cotacao_02['indice05'].str.contains('I Preço Total\r')
preco_total3 = pagina3_cotacao_02['indice05'].str.replace('I Preço Total\r','')
preco_total3 = preco_total3[preco_total3.str.len() > 0]
preco_total3 = preco_total3[~preco_total3.str.contains('Qtde.\r')]
preco_total3 = preco_total3.reset_index(drop=True)
preco_total3 = preco_total3.apply(lambda x: str(x).replace(".",""))
preco_total3 = preco_total3.apply(lambda x: str(x).replace(",","."))
preco_total3 = preco_total3.astype('float64')
#mesclando os dados atrávés de cada indice formando uma tabela
df_mesclar03= descricao_material3.to_frame().merge(preco_unitario3,left_index=True,right_index=True)
df_mesclar03= descricao_material3.to_frame().merge(preco_unitario3,left_index=True,right_index=True)
Tabela_03= df_mesclar03.merge(preco_total3,left_index=True,right_index=True)
Tabela_03['indice02'] = Tabela_03['indice05'] / Tabela_03['indice04']
display(Tabela_03)
# Out:
#                   indice01  indice04  indice05   indice02
# 0                TRENA 5 M   14.6300    438.90  30.000000
# 1  ESTILETE PROFISSIONAL 6   11.4675    688.05  60.000000
# 2    ARCO DE SERRA FIXO 12   20.1500    604.50  30.000000
# 3      CHAVE COMBINADA 8MM    5.4117    324.70  59.999630
# 4     CHAVE COMBINADA 10MM    5.5867    335.20  59.999642
# 5     CHAVE COMBINADA 11MM    5.8133    348.80  60.000344
# 6     CHAVE COMBINADA 12MM    6.1558    369.35  60.000325
# 7     CHAVE COMBINADA 13MM    6.5400    392.40  60.000000

# %% [markdown]
# #PAGINA_04_TRAMONTINA

# %%
#Leitura do pdf
lista4_cotacao_02 = tabula.read_pdf(r"C:\Users\Hely Ribeiro Menezes\Documents\One Engenharia\Colab Notebooks\COTAÇAO_FERRAMENTAS\cdp19023051109003634960000000.pdf", pages="4")
pagina4_cotacao_02 = lista4_cotacao_02[0]
pagina4_cotacao_02.columns = ['indice01','indice02','indice03','indice04','indice05','indice06','indice07','indice08','indice09','indice10']
#Descrição material - Filtragem de descirção somente da tabela 01
descricao_material4 = pagina4_cotacao_02[pagina4_cotacao_02['indice01'].str.contains('Descrição\r')]
descricao_material4 = descricao_material4['indice01'].str.replace('Descrição\r','')
descricao_material4 = descricao_material4.reset_index(drop=True)
#Preço_Unitário - FIltragem de preço unitário da tabela1
preco_unitario4 = pagina4_cotacao_02[pagina4_cotacao_02['indice04'].str.len() > 0]
preco_unitario4 = pagina4_cotacao_02['indice04'].str.contains('Preço Unitário sem I\r')
preco_unitario4 = pagina4_cotacao_02['indice04'].str.replace('Preço Unitário sem I\r','')
preco_unitario4 = preco_unitario4[preco_unitario4.str.len() > 0]
preco_unitario4 = preco_unitario4[~preco_unitario4.str.contains('Emb.\r')]
preco_unitario4 = preco_unitario4.reset_index(drop=True)
preco_unitario4 = preco_unitario4.apply(lambda x: str(x).replace(",","."))
preco_unitario4 = preco_unitario4.astype('float64')
#Preço total - fitragem de preço total
preco_total4 = pagina4_cotacao_02[pagina4_cotacao_02['indice05'].str.len() > 0]
preco_total4 = pagina4_cotacao_02['indice05'].str.contains('I Preço Total\r')
preco_total4 = pagina4_cotacao_02['indice05'].str.replace('I Preço Total\r','')
preco_total4 = preco_total4[preco_total4.str.len() > 0]
preco_total4 = preco_total4[~preco_total4.str.contains('Qtde.\r')]
preco_total4 = preco_total4.reset_index(drop=True)
preco_total4 = preco_total4.apply(lambda x: str(x).replace(".",""))
preco_total4 = preco_total4.apply(lambda x: str(x).replace(",","."))
preco_total4 = preco_total4.astype('float64')
#mesclando os dados atrávés de cada indice formando uma tabela
df_mesclar04= descricao_material4.to_frame().merge(preco_unitario4,left_index=True,right_index=True)
df_mesclar04= descricao_material4.to_frame().merge(preco_unitario4,left_index=True,right_index=True)
Tabela_04= df_mesclar04.merge(preco_total4,left_index=True,right_index=True)
Tabela_04['indice02'] = Tabela_04['indice05'] / Tabela_04['indice04']
display(Tabela_04)
# Out:
#                indice01  indice04  indice05   indice02
# 0  CHAVE COMBINADA 15MM    7.4450     446.7  60.000000
# 1  CHAVE COMBINADA 17MM    8.6483     518.9  60.000231
# 2  CHAVE COMBINADA 19MM    9.4400     566.4  60.000000
# 3  CHAVE COMBINADA 24MM   14.9633     448.9  30.000067
# 4       CHAVE BIELA 8MM   10.2117     612.7  59.999804
# 5      CHAVE BIELA 10MM   10.5583     633.5  60.000189
# 6      CHAVE BIELA 13MM   13.4717     808.3  59.999852
# 7      CHAVE BIELA 14MM   13.9250     835.5  60.000000

# %% [markdown]
# #PAGINA_05_TRAMONTINA

# %%
#Leitura do pdf
lista5_cotacao_02 = tabula.read_pdf(r"C:\Users\Hely Ribeiro Menezes\Documents\One Engenharia\Colab Notebooks\COTAÇAO_FERRAMENTAS\cdp19023051109003634960000000.pdf", pages="5")
pagina5_cotacao_02 = lista5_cotacao_02[0]
pagina5_cotacao_02.columns = ['indice01','indice02','indice03','indice04','indice05','indice06','indice07','indice08','indice09','indice10']
#Descrição material - Filtragem de descirção somente da tabela 01
descricao_material5 = pagina5_cotacao_02[pagina5_cotacao_02['indice01'].str.contains('Descrição\r')]
descricao_material5 = descricao_material5['indice01'].str.replace('Descrição\r','')
descricao_material5 = descricao_material5.reset_index(drop=True)
#Preço_Unitário - FIltragem de preço unitário da tabela1
preco_unitario5 = pagina5_cotacao_02[pagina5_cotacao_02['indice04'].str.len() > 0]
preco_unitario5 = pagina5_cotacao_02['indice04'].str.contains('Preço Unitário sem I\r')
preco_unitario5 = pagina5_cotacao_02['indice04'].str.replace('Preço Unitário sem I\r','')
preco_unitario5 = preco_unitario5[preco_unitario5.str.len() > 0]
preco_unitario5 = preco_unitario5[~preco_unitario5.str.contains('Emb.\r')]
preco_unitario5 = preco_unitario5.reset_index(drop=True)
preco_unitario5 = preco_unitario5.apply(lambda x: str(x).replace(",","."))
preco_unitario5 = preco_unitario5.astype('float64')
#Preço total - fitragem de preço total
preco_total5 = pagina5_cotacao_02[pagina5_cotacao_02['indice05'].str.len() > 0]
preco_total5 = pagina5_cotacao_02['indice05'].str.contains('I Preço Total\r')
preco_total5 = pagina5_cotacao_02['indice05'].str.replace('I Preço Total\r','')
preco_total5 = preco_total5[preco_total5.str.len() > 0]
preco_total5 = preco_total5[~preco_total5.str.contains('Qtde.\r')]
preco_total5 = preco_total5.reset_index(drop=True)
preco_total5 = preco_total5.apply(lambda x: str(x).replace(".",""))
preco_total5 = preco_total5.apply(lambda x: str(x).replace(",","."))
preco_total5 = preco_total5.astype('float64')
#mesclando os dados atrávés de cada indice formando uma tabela
df_mesclar05= descricao_material5.to_frame().merge(preco_unitario5,left_index=True,right_index=True)
df_mesclar05= descricao_material5.to_frame().merge(preco_unitario5,left_index=True,right_index=True)
Tabela_05= df_mesclar05.merge(preco_total5,left_index=True,right_index=True)
Tabela_05['indice02'] = Tabela_05['indice05'] / Tabela_05['indice04']
display(Tabela_05)
# Out:
#                        indice01  indice04  indice05   indice02
# 0              CHAVE BIELA 17MM   15.5167    931.00  59.999871
# 1              CHAVE BIELA 19MM   16.6850   1001.10  60.000000
# 2                CATRACA 1/2 10   63.6033   1908.10  30.000016
# 3  SOQUETE ESTRIADO 1/2 - 10 MM    8.8233    264.70  30.000113
# 4  SOQUETE ESTRIADO 1/2 - 13 MM    8.8233    264.70  30.000113
# 5  SOQUETE ESTRIADO 1/2 - 17 MM    9.5583    286.75  30.000105
# 6  SOQUETE ESTRIADO 1/2 - 19 MM   10.8967    326.90  29.999908
# 7            CHAVE AJUSTAVEL 10   37.3183   2239.10  60.000054

# %% [markdown]
# #PAGINA_06_TRAMONTINA

# %%
#Leitura do pdf
lista6_cotacao_02 = tabula.read_pdf(r"C:\Users\Hely Ribeiro Menezes\Documents\One Engenharia\Colab Notebooks\COTAÇAO_FERRAMENTAS\cdp19023051109003634960000000.pdf", pages="6")
pagina6_cotacao_02 = lista6_cotacao_02[0]
pagina6_cotacao_02.columns = ['indice01','indice02','indice03','indice04','indice05','indice06','indice07','indice08','indice09','indice10']
#Descrição material - Filtragem de descirção somente da tabela 01
descricao_material6 = pagina6_cotacao_02[pagina6_cotacao_02['indice01'].str.contains('Descrição\r')]
descricao_material6 = descricao_material6['indice01'].str.replace('Descrição\r','')
descricao_material6 = descricao_material6.reset_index(drop=True)
#Preço_Unitário - FIltragem de preço unitário da tabela1
preco_unitario6 = pagina6_cotacao_02[pagina6_cotacao_02['indice04'].str.len() > 0]
preco_unitario6 = pagina6_cotacao_02['indice04'].str.contains('Preço Unitário sem I\r')
preco_unitario6 = pagina6_cotacao_02['indice04'].str.replace('Preço Unitário sem I\r','')
preco_unitario6 = preco_unitario6[preco_unitario6.str.len() > 0]
preco_unitario6 = preco_unitario6[~preco_unitario6.str.contains('Emb.\r')]
preco_unitario6 = preco_unitario6.reset_index(drop=True)
preco_unitario6 = preco_unitario6.apply(lambda x: str(x).replace(".",""))
preco_unitario6 = preco_unitario6.apply(lambda x: str(x).replace(",","."))
preco_unitario6 = preco_unitario6.astype('float64')
#Preço total - fitragem de preço total
preco_total6 = pagina6_cotacao_02[pagina6_cotacao_02['indice05'].str.len() > 0]
preco_total6 = pagina6_cotacao_02['indice05'].str.contains('I Preço Total\r')
preco_total6 = pagina6_cotacao_02['indice05'].str.replace('I Preço Total\r','')
preco_total6 = preco_total6[preco_total6.str.len() > 0]
preco_total6 = preco_total6[~preco_total6.str.contains('Qtde.\r')]
preco_total6 = preco_total6.reset_index(drop=True)
preco_total6 = preco_total6.apply(lambda x: str(x).replace(".",""))
preco_total6 = preco_total6.apply(lambda x: str(x).replace(",","."))
preco_total6 = preco_total6.astype('float64')
#mesclando os dados atrávés de cada indice formando uma tabela
df_mesclar06= descricao_material6.to_frame().merge(preco_unitario6,left_index=True,right_index=True)
df_mesclar06= descricao_material6.to_frame().merge(preco_unitario6,left_index=True,right_index=True)
Tabela_06= df_mesclar06.merge(preco_total6,left_index=True,right_index=True)
Tabela_06['indice02'] = Tabela_06['indice05'] / Tabela_06['indice04']
display(Tabela_06)
# Out:
#                               indice01   indice04  indice05   indice02
# 0                 ALICATE CRIMPADOR  9   289.6100   8688.30  30.000000
# 1        SERRA COPO BI-METALICA 25MM-1    24.2150    726.45  30.000000
# 2  JOGO DE LAPIS P/ CARPINTEIRO 40 PCS     1.2134     97.07  79.998352
# 3                CHAVE CANHAO IEC 10MM    74.5900   2237.70  30.000000
# 4         JOGO CHAVES HEXAGONAIS 9 PCS    24.2367    727.10  29.999959
# 5  MART. PERF.ROM. 1.9/16" 220V  1200W  1914.7800  57443.40  30.000000
# 6    PARAF/FUR. IMP. A BAT. LI ION 18V   996.6250  29898.75  30.000000
# 7       ESMERILHADEIRA 4.1/2 220V 850W   356.1900  10685.70  30.000000

# %% [markdown]
# #PAGINA_07_TRAMONTINA

# %%
#Leitura do pdf
lista1_cotacao_02 = tabula.read_pdf(r"C:\Users\Hely Ribeiro Menezes\Documents\One Engenharia\Colab Notebooks\COTAÇAO_FERRAMENTAS\cdp19023051109003634960000000.pdf", pages="7")
pagina1_cotacao_02 = lista1_cotacao_02[0]
pagina1_cotacao_02.columns = ['indice01','indice02','indice03','indice04','indice05','indice06','indice07','indice08','indice09','indice10']
#Descrição material - Filtragem de descirção somente da tabela 01
descricao_material1 = pagina1_cotacao_02[pagina1_cotacao_02['indice01'].str.contains('Descrição\r')]
descricao_material1 = descricao_material1['indice01'].str.replace('Descrição\r','')
descricao_material1 = descricao_material1.reset_index(drop=True)
#Preço_Unitário - FIltragem de preço unitário da tabela1
preco_unitario1 = pagina1_cotacao_02[pagina1_cotacao_02['indice04'].str.len() > 0]
preco_unitario1 = pagina1_cotacao_02['indice04'].str.contains('Preço Unitário sem I\r')
preco_unitario1 = pagina1_cotacao_02['indice04'].str.replace('Preço Unitário sem I\r','')
preco_unitario1 = preco_unitario1[preco_unitario1.str.len() > 0]
preco_unitario1 = preco_unitario1[~preco_unitario1.str.contains('Emb.\r')]
preco_unitario1 = preco_unitario1.reset_index(drop=True)
preco_unitario1 = preco_unitario1.apply(lambda x: str(x).replace(",","."))
preco_unitario1 = preco_unitario1.astype('float64')
#Preço total - fitragem de preço total
preco_total1 = pagina1_cotacao_02[pagina1_cotacao_02['indice05'].str.len() > 0]
preco_total1 = pagina1_cotacao_02['indice05'].str.contains('I Preço Total\r')
preco_total1 = pagina1_cotacao_02['indice05'].str.replace('I Preço Total\r','')
preco_total1 = preco_total1[preco_total1.str.len() > 0]
preco_total1 = preco_total1[~preco_total1.str.contains('Qtde.\r')]
preco_total1 = preco_total1.reset_index(drop=True)
preco_total1 = preco_total1.apply(lambda x: str(x).replace(".",""))
preco_total1 = preco_total1.apply(lambda x: str(x).replace(",","."))
preco_total1 = preco_total1.astype('float64')
#mesclando os dados atrávés de cada indice formando uma tabela
df_mesclar07= descricao_material1.to_frame().merge(preco_unitario1,left_index=True,right_index=True)
df_mesclar07= descricao_material1.to_frame().merge(preco_unitario1,left_index=True,right_index=True)
Tabela_07= df_mesclar07.merge(preco_total1,left_index=True,right_index=True)
Tabela_07['indice02'] = Tabela_07['indice05'] / Tabela_07['indice04']
display(Tabela_07)
# Out:
#                           indice01  indice04  indice05  indice02
# 0  FURADEIRA IMPACTO 1/2 220V 900W   328.175   9845.25      30.0
# 1        BOLSA PARA FERRAMENTAS 12   184.850   5545.50      30.0
# 2            BROCA PARA ACO 3.0 MM     2.905    174.30      60.0
# 3            BROCA PARA ACO 4.0 MM     3.107    186.42      60.0
# 4            BROCA PARA ACO 6.0 MM     4.672    280.32      60.0
# 5            BROCA PARA ACO 8.0 MM     8.320    499.20      60.0
# 6           BROCA PARA ACO 10.0 MM    13.800    828.00      60.0
# 7           BROCA PARA ACO 12.0 MM    20.004   1200.24      60.0

# %% [markdown]
# #PAGINA_08_TRAMONTINA

# %%
#Leitura do pdf
lista8_cotacao_02 = tabula.read_pdf(r"C:\Users\Hely Ribeiro Menezes\Documents\One Engenharia\Colab Notebooks\COTAÇAO_FERRAMENTAS\cdp19023051109003634960000000.pdf", pages="8")
pagina8_cotacao_02 = lista8_cotacao_02[0]
pagina8_cotacao_02.columns = ['indice01','indice02','indice03','indice04','indice05','indice06','indice07','indice08','indice09','indice10']
#Descrição material - Filtragem de descirção somente da tabela 01
descricao_material8 = pagina8_cotacao_02[pagina8_cotacao_02['indice01'].str.contains('Descrição\r')]
descricao_material8 = descricao_material8['indice01'].str.replace('Descrição\r','')
descricao_material8 = descricao_material8.reset_index(drop=True)
#Preço_Unitário - FIltragem de preço unitário da tabela1
preco_unitario8 = pagina8_cotacao_02[pagina8_cotacao_02['indice04'].str.len() > 0]
preco_unitario8 = pagina8_cotacao_02['indice04'].str.contains('Preço Unitário sem I\r')
preco_unitario8 = pagina8_cotacao_02['indice04'].str.replace('Preço Unitário sem I\r','')
preco_unitario8 = preco_unitario8[preco_unitario8.str.len() > 0]
preco_unitario8 = preco_unitario8[~preco_unitario8.str.contains('Emb.\r')]
preco_unitario8 = preco_unitario8.reset_index(drop=True)
preco_unitario8 = preco_unitario8.apply(lambda x: str(x).replace(",","."))
preco_unitario8 = preco_unitario8.astype('float64')
#Preço total - fitragem de preço total
preco_total8 = pagina8_cotacao_02[pagina8_cotacao_02['indice05'].str.len() > 0]
preco_total8 = pagina8_cotacao_02['indice05'].str.contains('I Preço Total\r')
preco_total8 = pagina8_cotacao_02['indice05'].str.replace('I Preço Total\r','')
preco_total8 = preco_total8[preco_total8.str.len() > 0]
preco_total8 = preco_total8[~preco_total8.str.contains('Qtde.\r')]
preco_total8 = preco_total8.reset_index(drop=True)
preco_total8 = preco_total8.apply(lambda x: str(x).replace(".",""))
preco_total8 = preco_total8.apply(lambda x: str(x).replace(",","."))
preco_total8 = preco_total8.astype('float64')
#mesclando os dados atrávés de cada indice formando uma tabela
df_mesclar08= descricao_material8.to_frame().merge(preco_unitario8,left_index=True,right_index=True)
df_mesclar08= descricao_material8.to_frame().merge(preco_unitario8,left_index=True,right_index=True)
Tabela_08= df_mesclar08.merge(preco_total8,left_index=True,right_index=True)
Tabela_08['indice02'] = Tabela_08['indice05'] / Tabela_08['indice04']
display(Tabela_08)
# Out:
#                               indice01  indice04  indice05    indice02
# 0                   LIMA PARA ENXADA 8   24.9700    749.10   30.000000
# 1    DISCO DE DESBASTE PARA ACOS 4.1/2    4.9858    299.15   60.000401
# 2        DISCO DE CORTE PARA ACO 4.1/2    3.3258    997.75  300.003007
# 3                  ALICATE UNIVERSAL 8   20.8700   1252.20   60.000000
# 4  TORQ. ESTALO P/ BITS 1/4  - 3-15N.M  763.4700  22904.10   30.000000
# 5                 MARTELO DE UNHA 34MM   40.0383   1201.15   30.000025
# 6    CAVADEIRA TIPO LIGHT C/CABO 145CM   78.8000   2364.00   30.000000
# 7  ENXADA LARGA CANAV 2,5 C/CABO 145CM   40.7100   1221.30   30.000000

# %% [markdown]
# #PAGINA_09_TRAMONTINA

# %%
#Leitura do pdf
lista9_cotacao_02 = tabula.read_pdf(r"C:\Users\Hely Ribeiro Menezes\Documents\One Engenharia\Colab Notebooks\COTAÇAO_FERRAMENTAS\cdp19023051109003634960000000.pdf", pages="9")
pagina9_cotacao_02 = lista9_cotacao_02[0]
pagina9_cotacao_02.columns = ['indice01','indice02','indice03','indice04','indice05','indice06','indice07','indice08','indice09','indice10']
#Descrição material - Filtragem de descirção somente da tabela 01
descricao_material9 = pagina9_cotacao_02[pagina9_cotacao_02['indice01'].str.contains('Descrição\r')]
descricao_material9 = descricao_material9['indice01'].str.replace('Descrição\r','')
descricao_material9 = descricao_material9.reset_index(drop=True)
#Preço_Unitário
preco_unitario9 = pagina9_cotacao_02[pagina9_cotacao_02['indice04'].str.len() > 0]
preco_unitario9 = pagina9_cotacao_02['indice04'].str.contains('Preço Unitário sem I\r')
preco_unitario9 = pagina9_cotacao_02['indice04'].str.replace('Preço Unitário sem I\r','')
preco_unitario9 = preco_unitario9[preco_unitario9.str.len() > 0]
preco_unitario9 = preco_unitario9[~preco_unitario9.str.contains('Emb.\r')]
preco_unitario9 = preco_unitario9.reset_index(drop=True)
preco_unitario9 = preco_unitario9.apply(lambda x: str(x).replace(",","."))
preco_unitario9 = preco_unitario9.astype('float64')
#Preço total - fitragem de preço total
preco_total9 = pagina9_cotacao_02[pagina9_cotacao_02['indice05'].str.len() > 0]
preco_total9 = pagina9_cotacao_02['indice05'].str.contains('I Preço Total\r')
preco_total9 = pagina9_cotacao_02['indice05'].str.replace('I Preço Total\r','')
preco_total9 = preco_total9[preco_total9.str.len() > 0]
preco_total9 = preco_total9[~preco_total9.str.contains('Qtde.\r')]
preco_total9 = preco_total9.reset_index(drop=True)
preco_total9 = preco_total9.apply(lambda x: str(x).replace(".",""))
preco_total9 = preco_total9.apply(lambda x: str(x).replace(",","."))
preco_total9 = preco_total9.astype('float64')
#mesclando os dados atrávés de cada indice formando uma tabela
df_mesclar09= descricao_material9.to_frame().merge(preco_unitario9,left_index=True,right_index=True)
df_mesclar09= descricao_material9.to_frame().merge(preco_unitario9,left_index=True,right_index=True)
Tabela_09= df_mesclar09.merge(preco_total9,left_index=True,right_index=True)
Tabela_09['indice02'] = Tabela_09['indice05'] / Tabela_09['indice04']
display(Tabela_09)
# Out:
#                             indice01  indice04  indice05   indice02
# 0  ENXADAO ESTREITO 2,5 C/CABO 130CM   46.3200   1389.60  30.000000
# 1             PA DE BICO C/CABO 71CM   22.8900    686.70  30.000000
# 2            MARRETA OITAVADA 3.000G  141.5800   4247.40  30.000000
# 3                      TALHADEIRA 10   21.8367    655.10  29.999954
# 4            SERROTE PROFISSIONAL 20   34.1583   1024.75  30.000029
# 5                        ESQUADRO 12   37.3200   1119.60  30.000000
# 6            CH.VELA 16MM E MANIPULO   25.5533    766.60  30.000039
# 7       MANGUEIRA CRISTAL 5/16  50 M   33.0000     33.00   1.000000

# %% [markdown]
# #PAGINA_10_TRAMONTINA

# %%
#Leitura do pdf
lista10_cotacao_02 = tabula.read_pdf(r"C:\Users\Hely Ribeiro Menezes\Documents\One Engenharia\Colab Notebooks\COTAÇAO_FERRAMENTAS\cdp19023051109003634960000000.pdf", pages="10")
pagina10_cotacao_02 = lista10_cotacao_02[0]
pagina10_cotacao_02.columns = ['indice01','indice02','indice03','indice04','indice05','indice06','indice07','indice08','indice09','indice10']
#Descrição material - Filtragem de descirção somente da tabela 01
descricao_material10 = pagina10_cotacao_02[pagina10_cotacao_02['indice01'].str.contains('Descrição\r')]
descricao_material10 = descricao_material10['indice01'].str.replace('Descrição\r','')
descricao_material10 = descricao_material10.reset_index(drop=True)
#Preço_Unitário - FIltragem de preço unitário da tabela1
preco_unitario10 = pagina10_cotacao_02[pagina10_cotacao_02['indice04'].str.len() > 0]
preco_unitario10 = pagina10_cotacao_02['indice04'].str.contains('Preço Unitário sem I\r')
preco_unitario10 = pagina10_cotacao_02['indice04'].str.replace('Preço Unitário sem I\r','')
preco_unitario10 = preco_unitario10[preco_unitario10.str.len() > 0]
preco_unitario10 = preco_unitario10[~preco_unitario10.str.contains('Emb.\r')]
preco_unitario10 = preco_unitario10.reset_index(drop=True)
preco_unitario10 = preco_unitario10.apply(lambda x: str(x).replace(",","."))
preco_unitario10 = preco_unitario10.astype('float64')
#Preço total - fitragem de preço total
preco_total10 = pagina10_cotacao_02[pagina10_cotacao_02['indice05'].str.len() > 0]
preco_total10 = pagina10_cotacao_02['indice05'].str.contains('I Preço Total\r')
preco_total10 = pagina10_cotacao_02['indice05'].str.replace('I Preço Total\r','')
preco_total10 = preco_total10[preco_total10.str.len() > 0]
preco_total10 = preco_total10[~preco_total10.str.contains('Qtde.\r')]
preco_total10 = preco_total10.reset_index(drop=True)
preco_total10 = preco_total10.apply(lambda x: str(x).replace(".",""))
preco_total10 = preco_total10.apply(lambda x: str(x).replace(",","."))
preco_total10 = preco_total10.astype('float64')
#mesclando os dados atrávés de cada indice formando uma tabela
df_mesclar10= descricao_material10.to_frame().merge(preco_unitario10,left_index=True,right_index=True)
df_mesclar10= descricao_material10.to_frame().merge(preco_unitario10,left_index=True,right_index=True)
Tabela_10= df_mesclar10.merge(preco_total10,left_index=True,right_index=True)
Tabela_10['indice02'] = Tabela_10['indice05'] / Tabela_10['indice04']
display(Tabela_10)
# Out:
#                         indice01  indice04  indice05   indice02
# 0  PONTEIRA PONTA CRUZADA 8X80MM   17.3133    1558.2  90.000173
# 1    PONTEIRA PONTA CHATA 7X36MM   10.6933     962.4  90.000281

# %% [markdown]
# # UNINOS TODOS OS DATAFRAME E SALVANDO EM EXCEL

# %%
cotacao_02 = pd.concat([Tabela_01,Tabela_02,Tabela_03,Tabela_04,Tabela_05,Tabela_06,Tabela_07,Tabela_08,Tabela_09,Tabela_10],ignore_index=True)
display_html(cotacao_02)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>indice01</th>
#       <th>indice04</th>
#       <th>indice05</th>
#       <th>indice02</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>ALICATE CORTE DIAGONAL 6</td>
#       <td>20.8700</td>
#       <td>1252.2</td>
#       <td>60.000000</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>CH FENDA CHATA ISOLADA 3X150 1/8X6</td>
#       <td>8.0200</td>
#       <td>240.6</td>
#       <td>30.000000</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>CH FENDA CHATA ISOLADA 5X150 3/16X6</td>
#       <td>9.2400</td>
#       <td>277.2</td>
#       <td>30.000000</td>
# ...

# %%
dataframe_excel = pd.ExcelWriter('orcamento_Tramontina.xlsx')
cotacao_02.to_excel(dataframe_excel)
dataframe_excel.save()
