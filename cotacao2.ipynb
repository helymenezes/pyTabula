# %%
# !pip install tabula-py
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 43.2 MB/s eta 0:00:00
# ...

# %%
import tabula
import pandas as pd
from IPython.core.display import display_html
import re

# %%
# listas_cotacao_02 = tabula.read_pdf(r"/content/drive/MyDrive/Colab/COTAÇAO_FERRAMENTAS/cdp19023051109003634960000000.pdf", pages="all")
# paginas_cotacao_02 = listas_cotacao_02[0]

# %%
# for cotacao_02 in listas_cotacao_02:
#     display(cotacao_02)

# %%
#Leitura do pdf
lista1_cotacao_02 = tabula.read_pdf(r"/content/drive/MyDrive/Colab/COTAÇAO_FERRAMENTAS/cdp19023051109003634960000000.pdf", pages="1")
pagina1_cotacao_02 = lista1_cotacao_02[0]
pagina1_cotacao_02.columns = ['indice01','indice02','indice03','indice04','indice05','indice06','indice07','indice08','indice09','indice10']

#Descrição material - Filtragem de descirção somente da tabela 01
descricao_material1 = pagina1_cotacao_02[pagina1_cotacao_02['indice01'].str.contains('Descrição\r')]
descricao_material1 = descricao_material1['indice01'].str.replace('Descrição\r','')
descricao_material1 = descricao_material1.reset_index(drop=True)


#Leitura do pdf
lista1_cotacao_02 = tabula.read_pdf(r"/content/drive/MyDrive/Colab/COTAÇAO_FERRAMENTAS/cdp19023051109003634960000000.pdf", pages="1")
pagina1_cotacao_02 = lista1_cotacao_02[0]
pagina1_cotacao_02.columns = ['indice01','indice02','indice03','indice04','indice05','indice06','indice07','indice08','indice09','indice10']

#Descrição material - Filtragem de descirção somente da tabela 01
descricao_material1 = pagina1_cotacao_02[pagina1_cotacao_02['indice01'].str.contains('Descrição\r')]
descricao_material1 = descricao_material1['indice01'].str.replace('Descrição\r','')
descricao_material1 = descricao_material1.reset_index(drop=True)


#Preço_Unitário - FIltragem de preço unitário da tabela1
preco_unitario1 = pagina1_cotacao_02[pagina1_cotacao_02['indice04'].str.len() > 0]
preco_unitario1 = pagina1_cotacao_02['indice04'].str.contains('Preço Unitário sem I\r')
preco_unitario1 = pagina1_cotacao_02['indice04'].str.replace('Preço Unitário sem I\r','')
preco_unitario1 = preco_unitario1[preco_unitario1.str.len() > 0]
preco_unitario1 = preco_unitario1[~preco_unitario1.str.contains('Emb.\r1')]
preco_unitario1 = preco_unitario1.reset_index(drop=True)
preco_unitario1 = preco_unitario1.apply(lambda x: str(x).replace(",","."))
preco_unitario1 = preco_unitario1.astype('float64')

# #Quantidade - FIltragem de quantidade da tabela1
# quantidade_1 = pagina1_cotacao_02[pagina1_cotacao_02['indice05'].str.len() > 0]
# quantidade_1 = pagina1_cotacao_02['indice05'].str.contains('Qtde.\r')
# quantidade_1 = pagina1_cotacao_02['indice05'].str.replace('Qtde.\r','')
# quantidade_1 = quantidade_1[quantidade_1.str.len() > 0]
# quantidade_1 = quantidade_1[~quantidade_1.str.contains('Preço Total\r')]
# quantidade_1 = quantidade_1.reset_index(drop=True)

#Preço total - fitragem de preço total

preco_total1 = pagina1_cotacao_02[pagina1_cotacao_02['indice05'].str.len() > 0]
preco_total1 = pagina1_cotacao_02['indice05'].str.contains('I Preço Total\r')
preco_total1 = pagina1_cotacao_02['indice05'].str.replace('I Preço Total\r','')
preco_total1 = preco_total1[preco_total1.str.len() > 0]
preco_total1 = preco_total1[~preco_total1.str.contains('Qtde.\r30')]
preco_total1 = preco_total1.reset_index(drop=True)
preco_total1 = preco_total1.apply(lambda x: str(x).replace(",","."))
#preco_total1 = float(preco_total1.replace(',','.'))
preco_total1 = preco_total1.astype('float')
#mesclando os dados atrávés de cada indice formando uma tabela

df_mesclar01= descricao_material1.to_frame().merge(preco_unitario1,left_index=True,right_index=True)
df_mesclar01= descricao_material1.to_frame().merge(preco_unitario1,left_index=True,right_index=True)
Tabela_01= df_mesclar01.merge(preco_total1,left_index=True,right_index=True)
#Tabela_01['indice02'] = Tabela_01['indice05'] / Tabela_01['indice04']


#display
#display(descricao_material1)
#display(quantidade_1)
#display(preco_unitario1)
display(preco_total1)
display(Tabela_01)
#display(cotacao_tabela_01)
# Out:
# WARNING:tabula.io:Got stderr: May 19, 2023 4:44:35 PM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font LiberationSans for base font Symbol
# May 19, 2023 4:44:35 PM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font LiberationSans for base font ZapfDingbats
#
# WARNING:tabula.io:Got stderr: May 19, 2023 4:44:38 PM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font LiberationSans for base font Symbol
# May 19, 2023 4:44:38 PM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font LiberationSans for base font ZapfDingbats
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-55c9dddaca44> in <cell line: 51>()
#      49 preco_total1 = preco_total1.apply(lambda x: str(x).replace(",","."))
#      50 #preco_total1 = float(preco_total1.replace(',','.'))
# ...

# %%
lista2_cotacao_02 = tabula.read_pdf(r"/content/drive/MyDrive/Colab/COTAÇAO_FERRAMENTAS/cdp19023051109003634960000000.pdf", pages="2")
pagina2_cotacao_02 = lista2_cotacao_02[0] 
pagina2_cotacao_02.columns = ['indice01','indice02','indice03','indice04','indice05','indice06','indice07','indice08','indice09','indice10']
pagina2_cotacao_02 = pagina2_cotacao_02[pagina2_cotacao_02['indice01'].str.contains('Descrição\r')]
pagina2_cotacao_02['indice01'] = pagina2_cotacao_02['indice01'].str.replace('Descrição\r','')
pagina2_cotacao_02['indice01']
# Out:
# WARNING:tabula.io:Got stderr: May 19, 2023 2:37:24 AM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font LiberationSans for base font Symbol
# May 19, 2023 2:37:24 AM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font LiberationSans for base font ZapfDingbats
#
# <ipython-input-15-9874457e0fbf>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pagina2_cotacao_02['indice01'] = pagina2_cotacao_02['indice01'].str.replace('Descrição\r','')
# 1     CH. FENDA CRUZ. ISOLADA 6X200 1/4X8
# 4      CH. DE FENDA P. CHATA 3X125 -1/8X5
# 7     CH. DE FENDA P. CHATA 5X150 -3/16X6
# 10     CH. DE FENDA P. CHATA 6X200 -1/4X8
# 13     CH. DE FENDA P. CRUZ. 3X125 -1/8X5
# ...

# %%
lista3_cotacao_02 = tabula.read_pdf(r"/content/drive/MyDrive/Colab/COTAÇAO_FERRAMENTAS/cdp19023051109003634960000000.pdf", pages="3")
pagina3_cotacao_02 = lista3_cotacao_02[0]
pagina3_cotacao_02.columns = ['indice01','indice02','indice03','indice04','indice05','indice06','indice07','indice08','indice09','indice10']
pagina3_cotacao_02 = pagina3_cotacao_02[pagina3_cotacao_02['indice01'].str.contains('Descrição\r')]
pagina3_cotacao_02['indice01'] = pagina3_cotacao_02['indice01'].str.replace('Descrição\r','')


pagina3_cotacao_02['indice01']
# Out:
# WARNING:tabula.io:Got stderr: May 19, 2023 2:41:32 AM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font LiberationSans for base font Symbol
# May 19, 2023 2:41:33 AM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font LiberationSans for base font ZapfDingbats
#
# <ipython-input-18-244d3e90b031>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pagina3_cotacao_02['indice01'] = pagina3_cotacao_02['indice01'].str.replace('Descrição\r','')
# 1                   TRENA 5 M
# 4     ESTILETE PROFISSIONAL 6
# 7       ARCO DE SERRA FIXO 12
# 10        CHAVE COMBINADA 8MM
# 13       CHAVE COMBINADA 10MM
# 16       CHAVE COMBINADA 11MM
# 19       CHAVE COMBINADA 12MM
# ...

# %%
lista4_cotacao_02 = tabula.read_pdf(r"/content/drive/MyDrive/Colab/COTAÇAO_FERRAMENTAS/cdp19023051109003634960000000.pdf", pages="4")
pagina4_cotacao_02 = lista4_cotacao_02[0] 
pagina4_cotacao_02.columns = ['indice01','indice02','indice03','indice04','indice05','indice06','indice07','indice08','indice09','indice10']
pagina4_cotacao_02 = pagina4_cotacao_02[pagina4_cotacao_02['indice01'].str.contains('Descrição\r')]
pagina4_cotacao_02['indice01'] = pagina4_cotacao_02['indice01'].str.replace('Descrição\r','')
pagina4_cotacao_02['indice01']
# Out:
# WARNING:tabula.io:Got stderr: May 19, 2023 2:42:19 AM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font LiberationSans for base font Symbol
# May 19, 2023 2:42:19 AM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font LiberationSans for base font ZapfDingbats
#
# <ipython-input-20-b1f0d7aaea64>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pagina4_cotacao_02['indice01'] = pagina4_cotacao_02['indice01'].str.replace('Descrição\r','')
# 1     CHAVE COMBINADA 15MM
# 4     CHAVE COMBINADA 17MM
# 7     CHAVE COMBINADA 19MM
# 10    CHAVE COMBINADA 24MM
# 13         CHAVE BIELA 8MM
# 16        CHAVE BIELA 10MM
# 19        CHAVE BIELA 13MM
# 22        CHAVE BIELA 14MM
# ...

# %%
lista5_cotacao_02 = tabula.read_pdf(r"/content/drive/MyDrive/Colab/COTAÇAO_FERRAMENTAS/cdp19023051109003634960000000.pdf", pages="5")
pagina5_cotacao_02 = lista5_cotacao_02[0]
pagina5_cotacao_02.columns = ['indice01','indice02','indice03','indice04','indice05','indice06','indice07','indice08','indice09','indice10']
pagina5_cotacao_02 = pagina5_cotacao_02[pagina5_cotacao_02['indice01'].str.contains('Descrição\r')]
pagina5_cotacao_02['indice01'] = pagina5_cotacao_02['indice01'].str.replace('Descrição\r','')
display(pagina5_cotacao_02['indice01'])
# Out:
# WARNING:tabula.io:Got stderr: May 19, 2023 2:43:47 AM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font LiberationSans for base font Symbol
# May 19, 2023 2:43:47 AM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font LiberationSans for base font ZapfDingbats
#
# <ipython-input-21-5bdf0d7c99ea>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pagina5_cotacao_02['indice01'] = pagina5_cotacao_02['indice01'].str.replace('Descrição\r','')
# 1                 CHAVE BIELA 17MM
# 4                 CHAVE BIELA 19MM
# 7                   CATRACA 1/2 10
# 10    SOQUETE ESTRIADO 1/2 - 10 MM
# 13    SOQUETE ESTRIADO 1/2 - 13 MM
# 16    SOQUETE ESTRIADO 1/2 - 17 MM
# ...

# %%
lista6_cotacao_02 = tabula.read_pdf(r"/content/drive/MyDrive/Colab/COTAÇAO_FERRAMENTAS/cdp19023051109003634960000000.pdf", pages="6")
pagina6_cotacao_02 = lista6_cotacao_02[0]
pagina6_cotacao_02.columns = ['indice01','indice02','indice03','indice04','indice05','indice06','indice07','indice08','indice09','indice10']
pagina6_cotacao_02 = pagina6_cotacao_02[pagina6_cotacao_02['indice01'].str.contains('Descrição\r')]
pagina6_cotacao_02['indice01'] = pagina6_cotacao_02['indice01'].str.replace('Descrição\r','')
pagina6_cotacao_02['indice01']
# Out:
# WARNING:tabula.io:Got stderr: May 19, 2023 2:44:17 AM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font LiberationSans for base font Symbol
# May 19, 2023 2:44:17 AM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font LiberationSans for base font ZapfDingbats
#
# <ipython-input-22-a54b695c586b>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pagina6_cotacao_02['indice01'] = pagina6_cotacao_02['indice01'].str.replace('Descrição\r','')
# 1                    ALICATE CRIMPADOR  9
# 4           SERRA COPO BI-METALICA 25MM-1
# 7     JOGO DE LAPIS P/ CARPINTEIRO 40 PCS
# 10                  CHAVE CANHAO IEC 10MM
# 13           JOGO CHAVES HEXAGONAIS 9 PCS
# ...

# %%
lista7_cotacao_02 = tabula.read_pdf(r"/content/drive/MyDrive/Colab/COTAÇAO_FERRAMENTAS/cdp19023051109003634960000000.pdf", pages="7")
pagina7_cotacao_02 = lista7_cotacao_02[0]
pagina7_cotacao_02.columns = ['indice01','indice02','indice03','indice04','indice05','indice06','indice07','indice08','indice09','indice10']
pagina7_cotacao_02 = pagina7_cotacao_02[pagina7_cotacao_02['indice01'].str.contains('Descrição\r')]
pagina7_cotacao_02['indice01'] = pagina7_cotacao_02['indice01'].str.replace('Descrição\r','')


pagina7_cotacao_02['indice01']
# Out:
# WARNING:tabula.io:Got stderr: May 19, 2023 2:45:42 AM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font LiberationSans for base font Symbol
# May 19, 2023 2:45:42 AM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font LiberationSans for base font ZapfDingbats
#
# <ipython-input-24-e130d28b4668>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pagina7_cotacao_02['indice01'] = pagina7_cotacao_02['indice01'].str.replace('Descrição\r','')
# 1     FURADEIRA IMPACTO 1/2 220V 900W
# 4           BOLSA PARA FERRAMENTAS 12
# 7               BROCA PARA ACO 3.0 MM
# 10              BROCA PARA ACO 4.0 MM
# 13              BROCA PARA ACO 6.0 MM
# 16              BROCA PARA ACO 8.0 MM
# ...

# %%
lista8_cotacao_02 = tabula.read_pdf(r"/content/drive/MyDrive/Colab/COTAÇAO_FERRAMENTAS/cdp19023051109003634960000000.pdf", pages="8")
pagina8_cotacao_02 = lista8_cotacao_02[0]
pagina8_cotacao_02.columns = ['indice01','indice02','indice03','indice04','indice05','indice06','indice07','indice08','indice09','indice10']
pagina8_cotacao_02 = pagina8_cotacao_02[pagina8_cotacao_02['indice01'].str.contains('Descrição\r')]
pagina8_cotacao_02['indice01'] = pagina8_cotacao_02['indice01'].str.replace('Descrição\r','')


pagina8_cotacao_02['indice01']
# Out:
# WARNING:tabula.io:Got stderr: May 19, 2023 2:47:34 AM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font LiberationSans for base font Symbol
# May 19, 2023 2:47:34 AM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font LiberationSans for base font ZapfDingbats
#
# <ipython-input-27-a0ff6ec936b7>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pagina8_cotacao_02['indice01'] = pagina8_cotacao_02['indice01'].str.replace('Descrição\r','')
# 1                      LIMA PARA ENXADA 8
# 4       DISCO DE DESBASTE PARA ACOS 4.1/2
# 7           DISCO DE CORTE PARA ACO 4.1/2
# 10                    ALICATE UNIVERSAL 8
# 13    TORQ. ESTALO P/ BITS 1/4  - 3-15N.M
# ...

# %%
lista9_cotacao_02 = tabula.read_pdf(r"/content/drive/MyDrive/Colab/COTAÇAO_FERRAMENTAS/cdp19023051109003634960000000.pdf", pages="9")
pagina9_cotacao_02 = lista9_cotacao_02[0]
pagina9_cotacao_02.columns = ['indice01','indice02','indice03','indice04','indice05','indice06','indice07','indice08','indice09','indice10']
pagina9_cotacao_02 = pagina9_cotacao_02[pagina9_cotacao_02['indice01'].str.contains('Descrição\r')]
pagina9_cotacao_02['indice01'] = pagina9_cotacao_02['indice01'].str.replace('Descrição\r','')
pagina9_cotacao_02['indice01']
# Out:
# WARNING:tabula.io:Got stderr: May 19, 2023 2:46:33 AM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font LiberationSans for base font Symbol
# May 19, 2023 2:46:33 AM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font LiberationSans for base font ZapfDingbats
#
# <ipython-input-25-90b4f6cd8fbe>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pagina9_cotacao_02['indice01'] = pagina9_cotacao_02['indice01'].str.replace('Descrição\r','')
# 1     ENXADAO ESTREITO 2,5 C/CABO 130CM
# 4                PA DE BICO C/CABO 71CM
# 7               MARRETA OITAVADA 3.000G
# 10                        TALHADEIRA 10
# 13              SERROTE PROFISSIONAL 20
# ...

# %%
lista10_cotacao_02 = tabula.read_pdf(r"/content/drive/MyDrive/Colab/COTAÇAO_FERRAMENTAS/cdp19023051109003634960000000.pdf", pages="10")
pagina10_cotacao_02 = lista10_cotacao_02[0]
pagina10_cotacao_02.columns = ['indice01','indice02','indice03','indice04','indice05','indice06','indice07','indice08','indice09','indice10']
pagina10_cotacao_02 = pagina10_cotacao_02[pagina10_cotacao_02['indice01'].str.contains('Descrição\r')]
pagina10_cotacao_02['indice01'] = pagina10_cotacao_02['indice01'].str.replace('Descrição\r','')


pagina10_cotacao_02['indice01']
# Out:
# WARNING:tabula.io:Got stderr: May 19, 2023 2:47:12 AM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font LiberationSans for base font Symbol
# May 19, 2023 2:47:12 AM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font LiberationSans for base font ZapfDingbats
#
# <ipython-input-26-ebef1cf419c1>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pagina10_cotacao_02['indice01'] = pagina10_cotacao_02['indice01'].str.replace('Descrição\r','')
# 1    PONTEIRA PONTA CRUZADA 8X80MM
# 4      PONTEIRA PONTA CHATA 7X36MM
# Name: indice01, dtype: object

# %%
tabela_cotacao_02 = pd.concat([pagina1_cotacao_02,pagina3_cotacao_02,pagina4_cotacao_02,pagina5_cotacao_02,pagina6_cotacao_02,pagina7_cotacao_02,pagina8_cotacao_02,pagina9_cotacao_02,pagina10_cotacao_02],ignore_index=True)
display(tabela_cotacao_02)
# Out:
#                                indice01 indice02 indice03 indice04 indice05  \
# 0              ALICATE CORTE DIAGONAL 6      NaN      NaN      NaN      NaN
# 1    CH FENDA CHATA ISOLADA 3X150 1/8X6      NaN      NaN      NaN      NaN
# 2   CH FENDA CHATA ISOLADA 5X150 3/16X6      NaN      NaN      NaN      NaN
# 3   CH FENDA CHATA ISOLADA 6X200 -1/4X8      NaN      NaN      NaN      NaN
# 4   CH. FENDA CRUZ. ISOLADA 3X150 1/8X6      NaN      NaN      NaN      NaN
# ..                                  ...      ...      ...      ...      ...
# 59                          ESQUADRO 12      NaN      NaN      NaN      NaN
# 60              CH.VELA 16MM E MANIPULO      NaN      NaN      NaN      NaN
# 61         MANGUEIRA CRISTAL 5/16  50 M      NaN      NaN      NaN      NaN
# 62        PONTEIRA PONTA CRUZADA 8X80MM      NaN      NaN      NaN      NaN
# 63          PONTEIRA PONTA CHATA 7X36MM      NaN      NaN      NaN      NaN
#
#    indice06 indice07 indice08 indice09  indice10
# ...

# %%
dataframe_excel = pd.ExcelWriter('orcamento_ferrenorte.xlsx')
tabela_cotacao_02.to_excel(dataframe_excel)
dataframe_excel.save()
