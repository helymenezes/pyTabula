# %%
# !pip install tabula-py
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 56.2 MB/s eta 0:00:00
# ...

# %%
import tabula
import pandas as pd

# %%
lista_cotacao_03 = tabula.read_pdf(r"/content/drive/MyDrive/Colab/COTAÇAO_FERRAMENTAS/Proposta One 01100523.pdf", pages="all")
print(len(lista_cotacao_03))
# Out:
# 5

# %%
for cotacao_03 in lista_cotacao_03:
    display(cotacao_03)
# Out:
#     Itens                  Unnamed: 0 Preço (und) Impostos (und)  Quantidade  \
# 0     NaN           70-019 - ALLICATE    R$ 42,74        R$ 2,22        60.0
# 1     NaN        UNIVERSAL 8" (230MM)         NaN            NaN         NaN
# 2     NaN          ABNT 1.000V 70-019         NaN            NaN         NaN
# 3     NaN   84-054 - ALICATE DE CORTE    R$ 26,62        R$ 1,38        60.0
# 4     NaN      DIAGONAL PRO 6" 84-054         NaN            NaN         NaN
# 5     NaN       STMT60819-840 - CHAVE     R$ 4,55        R$ 0,24        30.0
# 6     NaN          EMBORRACHADA FENDA         NaN            NaN         NaN
# 7     NaN   RETA 1/8" X 5" STMT60819-         NaN            NaN         NaN
# 8     NaN                         840         NaN            NaN         NaN
# 9     NaN       STMT60823-840 - CHAVE     R$ 6,75        R$ 0,35        30.0
# 10    NaN          EMBORRACHADA FENDA         NaN            NaN         NaN
# ...

# %%
import pandas as pd

# Criando um DataFrame de exemplo
data = {'celula': ['ABC', 'DEF', 'GHI', 'JKL']}
df = pd.DataFrame(data)

# Função para extrair o primeiro caractere
def extrair_primeiro_caractere(texto):
    return texto[0]

# Aplicando a função ao DataFrame
#df['primeiro_caractere'] = df['celula'].apply(extrair_primeiro_caractere)

# Exibindo o DataFrame resultante
print(df)
# Out:
#   celula
# 0    ABC
# 1    DEF
# 2    GHI
# 3    JKL
