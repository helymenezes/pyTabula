# %%
import tabula
import pandas as pd
from IPython.core.display import display_html
import re
import openpyxl

# %% [markdown]
# #PAGINA_01_FERRONORTE

# %%
#Leitura do pdf
lista0_cotacao_03 = tabula.read_pdf(r"Proposta One 01100523.pdf", pages="all")
pagina0_cotacao_03 = lista0_cotacao_03[0]
pagina0_cotacao_03.columns = ['indice01','indice02','indice03','indice04','indice05','indice06']
#Descrição material - Filtragem de descirção somente da tabela 01
descricao_material1 = pagina0_cotacao_03.drop('indice01',axis=1)
descricao_material1 = descricao_material1.dropna()
descricao_material1 = descricao_material1.reset_index(drop=True)
descricao_material1 = descricao_material1['indice02']
#Preço_Unitário - FIltragem quantidade da tabela1
quantiade0 = pagina0_cotacao_03['indice05'].dropna()
quantiade0 = quantiade0.reset_index(drop=True)
quantiade0 = quantiade0.astype('float64')
#Preço total - fitragem de preço total
preco_total0 = pagina0_cotacao_03['indice06'].dropna()
preco_total0 = preco_total0.reset_index(drop=True)
preco_total0 = preco_total0.apply(lambda x: str(x).replace("R$ ",""))
preco_total0 = preco_total0.apply(lambda x: str(x).replace(".",""))
preco_total0 = preco_total0.apply(lambda x: str(x).replace(",","."))
preco_total0 = preco_total0.astype('float64')
#mesclando os dados atrávés de cada indice formando uma tabela
df_mesclar0= descricao_material1.to_frame().merge(quantiade0,left_index=True,right_index=True)
Tabela_0= df_mesclar0.merge(preco_total0,left_index=True,right_index=True)
Tabela_0['indice07'] = Tabela_0['indice06'] / Tabela_0['indice05']

display(Tabela_0)
# Out:
#                     indice02  indice05  indice06   indice07
# 0          70-019 - ALLICATE      60.0   2697.75  44.962500
# 1  84-054 - ALICATE DE CORTE      60.0   1680.25  28.004167
# 2      STMT60819-840 - CHAVE      30.0    143.60   4.786667
# 3      STMT60823-840 - CHAVE      30.0    213.03   7.101000
# 4      STMT60829-840 - CHAVE      30.0    239.86   7.995333
# 5      STMT60802-840 - CHAVE      30.0    150.86   5.028667
# 6      STMT60806-840 - CHAVE      30.0    213.35   7.111667
# 7      STMT60812-840 - CHAVE      30.0    236.38   7.879333
# 8       STHT60670 - CHAVE DE      60.0    142.02   2.367000
# 9    42-886S - NÍVEL GP BASE      60.0   1725.31  28.755167

# %% [markdown]
# #PAGINA_02_FERRONORTE

# %%
#Leitura do pdf
lista1_cotacao_03 = tabula.read_pdf(r"Proposta One 01100523.pdf", pages="all")
pagina1_cotacao_03  = lista1_cotacao_03[1]
pagina1_cotacao_03.columns = ['indice01','indice02','indice03','indice04','indice05']
#Descrição material - Filtragem de descirção somente da tabela 01
descricao_material1 = pagina1_cotacao_03.dropna()
descricao_material1 = descricao_material1.reset_index(drop=True)
descricao_material1 = descricao_material1['indice01']
#Preço_Unitário - FIltragem quantidade da tabela1
quantiade1 = pagina1_cotacao_03['indice04'].dropna()
quantiade1 = quantiade1.reset_index(drop=True)
quantiade1 = quantiade1.astype('float64')
#Preço total - fitragem de preço total
preco_total1 = pagina1_cotacao_03['indice05'].dropna()
preco_total1 = preco_total1.reset_index(drop=True)
preco_total1 = preco_total1.apply(lambda x: str(x).replace("R$ ",""))
preco_total1 = preco_total1.apply(lambda x: str(x).replace(".",""))
preco_total1 = preco_total1.apply(lambda x: str(x).replace(",","."))
preco_total1 = preco_total1.astype('float64')
#mesclando os dados atrávés de cada indice formando uma tabela
df_mesclar01= descricao_material1.to_frame().merge(quantiade1,left_index=True,right_index=True)
Tabela_01= df_mesclar01.merge(preco_total1,left_index=True,right_index=True)
Tabela_01['indice06'] = Tabela_01['indice05'] / Tabela_01['indice04']

display(Tabela_01)
# Out:
#                    indice01  indice04  indice05   indice06
# 0  STHT10321-840 - ESTILETE      60.0   1004.48  16.741333
# 1    20-206 - ARCO DE SERRA      24.0    542.33  22.597083
# 2     STMT80217-840 - Chave      60.0    321.28   5.354667
# 3     STMT80219-840 - Chave      60.0    344.64   5.744000
# 4     STMT80220-840 - Chave      60.0    356.63   5.943833
# 5     STMT80222-840 - Chave      60.0    390.08   6.501333
# 6     STMT80223-840 - Chave      60.0    401.44   6.690667
# 7     STMT80224-840 - Chave      60.0    400.18   6.669667
# 8     STMT80225-840 - Chave      60.0    456.99   7.616500
# 9     STMT80229-840 - Chave      60.0    557.98   9.299667

# %% [markdown]
# #PAGINA_03_FERRORTE

# %%
#Leitura do pdf
lista2_cotacao_03 = tabula.read_pdf(r"Proposta One 01100523.pdf", pages="all")
pagina2_cotacao_03 = lista2_cotacao_03[2]
pagina2_cotacao_03.columns = ['indice01','indice02','indice03','indice04','indice05']
#Descrição material - Filtragem de descirção somente da tabela 01
descricao_material2 = pagina2_cotacao_03.dropna()
descricao_material2 = descricao_material2.reset_index(drop=True)
descricao_material2 = descricao_material2['indice01']
#Preço_Unitário - FIltragem quantidade da tabela1
quantiade2 = pagina2_cotacao_03['indice04'].dropna()
quantiade2 = quantiade2.reset_index(drop=True)
quantiade2 = quantiade2.astype('float64')
#Preço total - fitragem de preço total
preco_total2 = pagina2_cotacao_03['indice05'].dropna()
preco_total2 = preco_total2.reset_index(drop=True)
preco_total2 = preco_total2.apply(lambda x: str(x).replace("R$ ",""))
preco_total2 = preco_total2.apply(lambda x: str(x).replace(".",""))
preco_total2 = preco_total2.apply(lambda x: str(x).replace(",","."))
preco_total2 = preco_total2.astype('float64')
#mesclando os dados atrávés de cada indice formando uma tabela
df_mesclar02= descricao_material2.to_frame().merge(quantiade2,left_index=True,right_index=True)
Tabela_02= df_mesclar02.merge(preco_total2,left_index=True,right_index=True)
Tabela_02['indice06'] = Tabela_02['indice05'] / Tabela_02['indice04']

display(Tabela_02)
# Out:
#                      indice01  indice04   indice05     indice06
# 0       STMT80239-840 - Chave      60.0    1010.55    16.842500
# 1    4-86-418 - SOQUETE LONGO      30.0     356.00    11.866667
# 2    4-86-421 - SOQUETE LONGO      30.0     356.00    11.866667
# 3    4-86-425 - SOQUETE LONGO      30.0     475.92    15.864000
# 4    4-86-427 - SOQUETE LONGO      30.0     475.92    15.864000
# 5    87-047 - CHAVE AJUSTÁVEL      60.0    2252.75    37.545833
# 6        DAH180016-SERRA COPO      60.0    1827.60    30.460000
# 7        D25773K-B2 - Martelo      30.0  125201.04  4173.368000
# 8        DT6821-QZ - Ponteiro      60.0    5592.43    93.207167
# 9  DWA0805 - Ponteiro SDS-Max      60.0    2344.28    39.071333

# %% [markdown]
# #PAGINA_04_FERRONORTE

# %%
#Leitura do pdf
lista3_cotacao_03 = tabula.read_pdf(r"Proposta One 01100523.pdf", pages="all")
pagina3_cotacao_03 = lista3_cotacao_03[3]
pagina3_cotacao_03.columns = ['indice01','indice02','indice03','indice04','indice05']
#Descrição material - Filtragem de descirção somente da tabela 01
descricao_material3 = pagina3_cotacao_03.dropna()
descricao_material3 = descricao_material3.reset_index(drop=True)
descricao_material3 = descricao_material3['indice01']
#Preço_Unitário - FIltragem quantidade da tabela1
quantiade3 = pagina3_cotacao_03['indice04'].dropna()
quantiade3 = quantiade3.reset_index(drop=True)
quantiade3 = quantiade3.astype('float64')
#Preço total - fitragem de preço total
preco_total3 = pagina3_cotacao_03['indice05'].dropna()
preco_total3 = preco_total3.reset_index(drop=True)
preco_total3 = preco_total3.apply(lambda x: str(x).replace("R$ ",""))
preco_total3 = preco_total3.apply(lambda x: str(x).replace(".",""))
preco_total3 = preco_total3.apply(lambda x: str(x).replace(",","."))
preco_total3 = preco_total3.astype('float64')
#mesclando os dados atrávés de cada indice formando uma tabela
prdf_mesclar03= descricao_material3.to_frame().merge(quantiade3,left_index=True,right_index=True)
Tabela_03= prdf_mesclar03.merge(preco_total3,left_index=True,right_index=True)
Tabela_03['indice06'] = Tabela_03['indice05'] / Tabela_03['indice04']

display(Tabela_03)
# Out:
#                       indice01  indice04  indice05    indice06
# 0               DCF7871D2-BR -      30.0  29966.85  998.895000
# 1                DCD7781D2BR -      30.0  24018.42  800.614000
# 2  DWE4010-B2 - Esmerilhadeira      30.0   7715.47  257.182333
# 3      DWD502B2 - Furadeira de      30.0   7207.99  240.266333
# 4     DWA30300G - Gold Ferrous      60.0    148.96    2.482667
# 5     DWA30400G - Broca de aço      60.0    165.37    2.756167
# 6     DWA30600G - Gold Ferrous      60.0    288.46    4.807667
# 7     DWA30800G - Broca de aço      60.0    480.97    8.016167
# 8     BDHT22144 - LIMA CHATA -      24.0    378.97   15.790417
# 9     DW84405 - Disco Desbaste      60.0    417.60    6.960000

# %% [markdown]
# #PAGINA_05_FERRO

# %%
#Leitura do pdf
lista4_cotacao_03 = tabula.read_pdf(r"Proposta One 01100523.pdf", pages="all")
pagina4_cotacao_03 = lista4_cotacao_03[4]
pagina4_cotacao_03.columns = ['indice01','indice02','indice03','indice04','indice05']

#Descrição material - Filtragem de descirção somente da tabela 01

#descricao_material4 = pagina4_cotacao_03.drop('indice01',axis=1)
descricao_material4 = pagina4_cotacao_03.dropna()
descricao_material4 = descricao_material4.reset_index(drop=True)
descricao_material4 = descricao_material4['indice01']

#Preço_Unitário - FIltragem quantidade da tabela1

quantiade4 = pagina4_cotacao_03['indice04'].dropna()
quantiade4 = quantiade4.reset_index(drop=True)
quantiade4 = quantiade4.astype('float64')

#Preço total - fitragem de preço total

preco_total4 = pagina4_cotacao_03['indice05'].dropna()
preco_total4 = preco_total4.reset_index(drop=True)
preco_total4 = preco_total4.apply(lambda x: str(x).replace("R$ ",""))
preco_total4 = preco_total4.apply(lambda x: str(x).replace(".",""))
preco_total4 = preco_total4.apply(lambda x: str(x).replace(",","."))
preco_total4 = preco_total4.astype('float64')

#mesclando os dados atrávés de cada indice formando uma tabela

df_mesclar04= descricao_material4.to_frame().merge(quantiade4,left_index=True,right_index=True)
Tabela_04= df_mesclar04.merge(preco_total4,left_index=True,right_index=True)
Tabela_04['indice06'] = Tabela_04['indice05'] / Tabela_04['indice04']

display(Tabela_04)
# Out:
#                    indice01  indice04  indice05    indice06
# 0         51-424S - MARTELO      30.0   1228.32   40.944000
# 1  16-313 - TALHADEIRA 3/4"      30.0    835.39   27.846333
# 2          15-561 - SERROTE      30.0   1843.74   61.458000
# 3         46-536 - ESQUADRO      30.0   1410.18   47.006000
# 4   SCL020-B2 - LANTERNA DE      30.0   2056.17   68.539000
# 5    SB201-BR - BATERIA 20V      30.0   5425.11  180.837000
# 6     SC125-BR - CARREGADOR      32.0   3745.73  117.054063

# %%
cotacao_03 = pd.concat([Tabela_01,Tabela_02,Tabela_03,Tabela_04],ignore_index=True)
display_html(cotacao_03)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>indice01</th>
#       <th>indice04</th>
#       <th>indice05</th>
#       <th>indice06</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>STHT10321-840 - ESTILETE</td>
#       <td>60.0</td>
#       <td>1004.48</td>
#       <td>16.741333</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>20-206 - ARCO DE SERRA</td>
#       <td>24.0</td>
#       <td>542.33</td>
#       <td>22.597083</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>STMT80217-840 - Chave</td>
#       <td>60.0</td>
#       <td>321.28</td>
#       <td>5.354667</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>STMT80219-840 - Chave</td>
#       <td>60.0</td>
#       <td>344.64</td>
#       <td>5.744000</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>STMT80220-840 - Chave</td>
#       <td>60.0</td>
#       <td>356.63</td>
#       <td>5.943833</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>STMT80222-840 - Chave</td>
#       <td>60.0</td>
#       <td>390.08</td>
#       <td>6.501333</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>STMT80223-840 - Chave</td>
#       <td>60.0</td>
#       <td>401.44</td>
#       <td>6.690667</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>STMT80224-840 - Chave</td>
#       <td>60.0</td>
#       <td>400.18</td>
#       <td>6.669667</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>STMT80225-840 - Chave</td>
#       <td>60.0</td>
#       <td>456.99</td>
#       <td>7.616500</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>STMT80229-840 - Chave</td>
#       <td>60.0</td>
#       <td>557.98</td>
#       <td>9.299667</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>STMT80239-840 - Chave</td>
#       <td>60.0</td>
#       <td>1010.55</td>
#       <td>16.842500</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td